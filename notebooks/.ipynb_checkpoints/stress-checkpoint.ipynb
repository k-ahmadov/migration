# %%
import sys
work_dir = '/home/kahmadov/phd/coupling/'
sys.path.append(f'{work_dir}/modules/')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

plt.rcParams["font.size"] = 16

# %%
work_dir="/home/kahmadov/phd/migration"

with open(f'{work_dir}/results/results_fvm.pkl', 'rb') as f:
    results_fvm = pickle.load(f)

with open(f'{work_dir}/results/parameters.pkl', 'rb') as f:
    parameters = pickle.load(f)

# %%
def pressure(s, params):
    wi, kn, p0, L, zeta, theta, t, D = (
        params[k] for k in ("wi", "kn", "p0", "L", "zeta", "theta", "t", "D")
    )
    w0 = wi + p0 / kn
    x, w = sds.dimensionalize(zeta, theta, t, D, w0, L)
    x_sym, w_sym = sds.symmetrize(x, w)
    p_sym = kn * (w_sym - wi)
    return np.interp(s * L, x_sym, p_sym) / p0

def run_simulation(**params):
    lam = params["kn"] * params["L"] / params["E_"]
    x_hat, sn_hat, p_hat_out = es.calc_sn_hat(lam, params, pressure, n=2**10)
    mask = x_hat >= 0
    return {
        "t": params["t"],
        "D": params["D"],
        "x": x_hat[mask] * params["L"],
        "p": p_hat_out[mask] * params["p0"],
        "sn": sn_hat[mask] * params["p0"],
    }

# %%
base_params = {
    "L": 100,
    "E_": 64e9,
    "wi": 1e-4,
    "p0": 9e6,
    "mu": 1e-3,
}
